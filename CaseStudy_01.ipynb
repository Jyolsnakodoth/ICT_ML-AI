# %% [markdown]
# #**Predicting Housing Prices for regions in the USA using Liner Regression**

# %% [markdown]
# ##Importing librarires

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Loading csv data to dataframe

# %%
df=pd.read_csv('/content/USA_Housing.csv')

# %% [markdown]
# ##Checking data - columns and null values

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.isna().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %% [markdown]
# ##Statistical datas of the dataframe

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ##Pair plot for visualisation

# %%
sns.pairplot(df, size=2.5)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ##Checking the correlation among all the columns

# %%
df.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# ##splitting data into an X array that contains the features and y array with the target variable

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
X=df.drop(['Price','Address'],axis=1)

# %%
y=df['Price']

# %%
X.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population
# 0                          4.09     23086.800503
# 1                          3.09     40173.072174
# 2                          5.13     36882.159400
# 3                          3.26     34310.242831
# 4                          4.23     26354.109472

# %%
y.head()
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# Name: Price, dtype: float64

# %% [markdown]
# ##Training the Model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

# %% [markdown]
# ###Importing linear regression algorithm

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %% [markdown]
# ###Training the Data Model

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##Evaluating the model

# %%
lr.intercept_
# Out:
# -2631944.716031013

# %% [markdown]
# ##Model prdiction

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([1194143.70465493, 1186645.7544525 , 1046510.91333488, ...,
#         769437.58350318, 1588033.50012405, 1732983.94327977])

# %% [markdown]
# ##Plotting the linear regression model

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##Calculating the loss function

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 80713.28403262046
# MSE: 10194854910.630447
# RMSE: 100969.5741826737

# %% [markdown]
# ##Regression score function

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.9175905242467242
